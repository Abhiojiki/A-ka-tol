# %% [markdown]
# Import Packages

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import  KNeighborsClassifier

# %% [markdown]
# IMPORT DATA

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
x_train = np.load("X_train_new.npy")
y_train = np.load("Y_train.npy")

print(type(x_train), type(y_train))
# Out:
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %%
print(x_train.shape,y_train.shape)
# Out:
# (68, 30000) (68, 1)

# %%
print(y_train[-5:])
# Out:
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]]

# %%
plt.imshow(x_train[0].reshape(100,100,3))

# %% [markdown]
# ## Create MODEL

# %%
knn=KNeighborsClassifier()
# train 
knn.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
# make pridiction # testing the model 
knn.predict(x_train[:5].reshape(5,-1))
# Out:
# array([0.])

# %%
y_train[:5]
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        [0.],
#        [0.]])

# %%
print(y_train[5])
plt.imshow(x_train[5].reshape(100,100,-1))
# Out:
# [0.]

# %%
(x_train[5].reshape(1,-1)).shape

# %%
knn.predict(x_train[:5])
# Out:
# array([0., 0., 0., 0., 0.])

# %%
x_train[8].shape
# Out:
# (30000,)
